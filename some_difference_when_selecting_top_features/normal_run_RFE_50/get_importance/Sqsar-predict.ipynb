# %%
import joblib
import os,sys
# sys.path.append(r"C:\Users\Jerry Wang\Desktop\Paper_final_collection\lmax\test\get_importance")
import pandas as pd
import numpy as np

# %%
model_file = r"total_model_RFE50_kfold10_LGBMRegressor_225.model"

# %%
input_df = pd.read_csv(r"train0.8.csv")

# %%
feature_df = input_df.iloc[:, :-1]
print(feature_df.shape)
# Out:
# (181, 45)

# %%
model = joblib.load(model_file)

# %%
var_filter = model.variance_filter

# %%
feature_df_var = feature_df.loc[:,var_filter.get_support()]
print(feature_df_var.shape)
# Out:
# (181, 45)

# %%
feature_df_sele = feature_df_var.loc[:,model.selector.get_support()]
print(feature_df_sele.shape)
# Out:
# (181, 45)

# %%
importances = []
for m in model.models:
    importances.append(m.feature_importances_)

# %%
importances = np.mean(importances, axis=0)
importances.shape
# Out:
# (45,)

# %%
df_importance = pd.DataFrame([feature_df_sele.columns, importances], index=["feature_name", "importance"]).T
df_importance
# Out:
#               feature_name importance
# 0                     homo   0.014410
# 1                     lumo   0.036783
# 2             dipolemoment   0.016082
# 3                      hso   0.010093
# 4                Hso_T1_G0   0.021241
# 5       oscilator strength   0.012806
# 6          emission energy   0.378016
# 7   electron_density_at_Pt   0.007561
# 8                   s1_1_1   0.011347
# 9                   s1_1_2   0.015337
# 10                  s1_2_1   0.018509
# 11                  s1_2_2   0.041650
# 12                  s2_1_1   0.012108
# 13                  s2_1_2   0.017297
# 14                  s2_2_1   0.013466
# 15                  s2_2_2   0.014401
# 16                  s3_1_1   0.011541
# 17                  s3_1_2   0.031564
# 18                  s3_2_1   0.015354
# 19                  s3_2_2   0.020781
# 20                  t1_1_1   0.019141
# 21                  t1_1_2   0.004666
# 22                  t1_2_1   0.013498
# 23                  t1_2_2   0.016194
# 24                  t2_1_1   0.006248
# 25                  t2_1_2   0.009256
# 26                  t2_2_1   0.012661
# 27                  t2_2_2   0.014327
# 28                  t3_1_1   0.009521
# 29                  t3_1_2   0.015477
# 30                  t3_2_1   0.014011
# 31                  t3_2_2   0.007948
# 32             atom_type_1   0.000550
# 33             atom_type_2   0.000925
# 34             atom_type_3   0.001736
# 35             atom_type_4   0.000438
# 36              distance_1   0.007169
# 37              distance_2   0.026222
# 38              distance_3   0.010561
# 39              distance_4   0.007656
# 40                   den_1   0.013881
# 41                   den_2   0.042565
# 42                   den_3   0.008810
# 43                   den_4   0.013424
# 44        refractive_index   0.002766

# %%
df_importance.sort_values(by="importance", ascending=False, inplace=True)
df_importance
# Out:
#               feature_name importance
# 6          emission energy   0.378016
# 41                   den_2   0.042565
# 11                  s1_2_2   0.041650
# 1                     lumo   0.036783
# 17                  s3_1_2   0.031564
# 37              distance_2   0.026222
# 4                Hso_T1_G0   0.021241
# 19                  s3_2_2   0.020781
# 20                  t1_1_1   0.019141
# 10                  s1_2_1   0.018509
# 13                  s2_1_2   0.017297
# 23                  t1_2_2   0.016194
# 2             dipolemoment   0.016082
# 29                  t3_1_2   0.015477
# 18                  s3_2_1   0.015354
# 9                   s1_1_2   0.015337
# 0                     homo   0.014410
# 15                  s2_2_2   0.014401
# 27                  t2_2_2   0.014327
# 30                  t3_2_1   0.014011
# 40                   den_1   0.013881
# 22                  t1_2_1   0.013498
# 14                  s2_2_1   0.013466
# 43                   den_4   0.013424
# 5       oscilator strength   0.012806
# 26                  t2_2_1   0.012661
# 12                  s2_1_1   0.012108
# 16                  s3_1_1   0.011541
# 8                   s1_1_1   0.011347
# 38              distance_3   0.010561
# 3                      hso   0.010093
# 28                  t3_1_1   0.009521
# 25                  t2_1_2   0.009256
# 42                   den_3   0.008810
# 31                  t3_2_2   0.007948
# 39              distance_4   0.007656
# 7   electron_density_at_Pt   0.007561
# 36              distance_1   0.007169
# 24                  t2_1_1   0.006248
# 21                  t1_1_2   0.004666
# 44        refractive_index   0.002766
# 34             atom_type_3   0.001736
# 33             atom_type_2   0.000925
# 32             atom_type_1   0.000550
# 35             atom_type_4   0.000438

# %%
df_importance.to_csv(r"descriptors_importance.csv",index = False)
